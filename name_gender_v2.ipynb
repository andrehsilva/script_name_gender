# %%
# !pip install genderbr
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for genderbr: filename=genderbr-0.1.2-py3-none-any.whl size=2245 sha256=55cf2a3b09997b25f788f0fde3409ecf699fab72e689222f047984f3d27fe001
#   Stored in directory: /root/.cache/pip/wheels/e0/4f/e6/14359ec7c6ea449b6ce8d41f15c6559da28004f2c4dc93ff37
# Successfully built genderbr
# ...

# %%
import pandas as pd
from genderbr import names

# Obter uma lista de nomes masculinos e femininos usando a função get_gender
nomes_masculinos = name('')
nomes_femininos = name('F')

# Verificar se a lista de nomes masculinos não está vazia
if nomes_masculinos:
    # Criar um DataFrame com os nomes masculinos e um índice numérico simples
    df_nomes_masculinos = pd.DataFrame({'nome': nomes_masculinos, 'índice': range(len(nomes_masculinos))})

    # Visualizar o DataFrame
    print(df_nomes_masculinos.head())
else:
    print("A lista de nomes masculinos está vazia.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-01f2077cea65> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from genderbr import names
#       3
#       4 # Obter uma lista de nomes masculinos e femininos usando a função get_gender
#       5 nomes_masculinos = name('')
#
# ImportError: cannot import name 'names' from 'genderbr' (/usr/local/lib/python3.10/dist-packages/genderbr/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
nomes_masculinos

# %%
# Caminho para o arquivo Excel
caminho_arquivo_excel = '/content/drive/MyDrive/Colab Notebooks/Conexia/name_gender_ias/name_gender.xlsx'

# Lendo o arquivo Excel
try:
    df = pd.read_excel(caminho_arquivo_excel)
except FileNotFoundError:
    print("Arquivo não encontrado.")
    exit()

# Verifica se a coluna 'nome_completo' está presente no DataFrame
if 'nome' not in df.columns:
    print("A coluna 'nome' não está presente no arquivo Excel.")
    exit()

# Extrair o primeiro nome e salvar em uma nova coluna 'primeiro_nome'
df['primeiro_nome'] = df['nome'].str.split().str.get(0)

df.head()

# %%
def identificar_genero(nome):
    # Obtém o gênero do nome
    genero = get_gender(nome)
    return genero

# Verifica se a coluna 'nome' está presente no DataFrame
if 'primeiro_nome' not in df.columns:
    print("A coluna 'primeiro_nome' não está presente no arquivo Excel.")
    exit()

# Aplica a função identificar_genero para cada nome na coluna 'nome' e adiciona o resultado em uma nova coluna 'genero'
df['genero'] = df['primeiro_nome'].apply(identificar_genero)


df.head()
# Out:
#                          nome primeiro_nome genero
# 0            Adalberto Castro     Adalberto      M
# 1  Adelmo Dos Santos Siqueira        Adelmo      M
# 2              Adenisia Sousa      Adenisia      F
# 3      Admilson Viana De Lima      Admilson      M
# 4        Adolpho Arias D´Elia       Adolpho      M

# %%
df_nomes = df.copy()

# %%
# Atualiza os valores na coluna 'genero' usando uma função lambda e uma expressão condicional ternária
df_nomes['genero'] = df_nomes['genero'].apply(lambda x: 'Masculino' if x == 'M' else ('Feminino' if x == 'F' else 'Desconhecido'))
df_nomes.head()
# Out:
#                          nome primeiro_nome     genero
# 0            Adalberto Castro     Adalberto  Masculino
# 1  Adelmo Dos Santos Siqueira        Adelmo  Masculino
# 2              Adenisia Sousa      Adenisia   Feminino
# 3      Admilson Viana De Lima      Admilson  Masculino
# 4        Adolpho Arias D´Elia       Adolpho  Masculino

# %%
df_nomes['genero_desconhecido_para_masculino'] = df_nomes['genero'].apply(lambda x: 'Masculino' if x == 'Desconhecido' else ('Feminino' if x == 'Feminino' else 'Masculino'))

# %%
df_nomes
# Out:
#                              nome primeiro_nome        genero  \
# 0                Adalberto Castro     Adalberto     Masculino
# 1      Adelmo Dos Santos Siqueira        Adelmo     Masculino
# 2                  Adenisia Sousa      Adenisia      Feminino
# 3          Admilson Viana De Lima      Admilson     Masculino
# 4            Adolpho Arias D´Elia       Adolpho     Masculino
# ...                           ...           ...           ...
# 3570  Yisell Maylin Castillo Wong        Yisell  Desconhecido
# 3571                 Yunguang Cai      Yunguang  Desconhecido
# 3572             Yuri Kato D´Elia          Yuri     Masculino
# 3573       Yurik Gama Jemciugovas         Yurik     Masculino
# 3574              Zara Silva Dias          Zara      Feminino
#
#      genero_desconhecido_para_masculino
# 0                             Masculino
# 1                             Masculino
# 2                              Feminino
# 3                             Masculino
# ...

# %%
df_nomes.to_excel("/content/drive/MyDrive/Colab Notebooks/Conexia/name_gender_ias/name_gender_output.xlsx")
